# %%
# only for development
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import numpy as np
from src.experiments.simple_demo import SimpleDemo

# %%
exp = SimpleDemo(N=100)

sgld_res = exp.run_sgld()
rej_res = exp.run_rejection()

# %%
# plot noise variances per iteration
exp.plot_posterior(sgld_res["samples"])

# %%
# plot rejection probability versus step size
exp.plot_diagnostics(sgld_res, rej_res)
